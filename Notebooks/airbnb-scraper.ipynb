# %%
import requests
import pprint
from bs4 import BeautifulSoup

pp = pprint.PrettyPrinter(indent=4)

# Get listing info
# URL = 'https://www.airbnb.com/s/homes?search_type=pagination&query=Boston%2C%20MA&checkin=2020-08-16&checkout=2020-08-22&adults=2&items_offset=0'
def getListings(city, state, checkin, checkout, adults='1', page='0', search_type='pagination'):
    # Build the URL
    baseurl = 'https://www.airbnb.com/s/homes?'

    # Add pagination
    items_offset = str(int(page) * 20)
    URL = baseurl + 'search_type=' + search_type + '&items_offset=' + items_offset
    
    # Add location
    query = city + '%2C%20' + state
    URL = URL + '&query=' + query
    
    # Add logistics
    URL = URL + '&checkin=' + checkin + '&checkout=' + checkout + '&adults=' + adults
    
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')

    listings = []

    links = soup.find_all('a')
    # GET LISTING NAME AND URL
    counter = 0
    for link in links:
        # We just want to add real listings, not all link names
        if link.get('data-check-info-section'):
            listing_name = link.get('aria-label')
            url = 'https://www.airbnb.com' + link.get('href')
            listings.append({'listing_name': listing_name, 'url': url})
            counter += 1

    # GET TOTAL PRICE
    spans = soup.find_all('span')
    counter = 0
    for span in spans:
        text = span.get_text()
        if text and 'total' in text:
            total = text.replace('$', '')
            total = total.replace(' total', '')
            listings[counter]['total_price'] = total
            counter += 1

    
    # GET SUPERHOST, LISTING_TYPE, RATING, NUM_REVIEWS
    divs = soup.find_all('div')
    counter = 0
    for div in divs:
        if counter < len(listings) and div.get_text() == listings[counter]['listing_name']:
            is_superhost = 'False'
            listing_type = ''
            rating = None
            num_reviews = '0'

            listing_info = div.previous_sibling
            for child in listing_info:
                if 'Entire ' in child.get_text() or 'Private ' in child.get_text():
                    listing_type = child.get_text()
                elif 'SUPERHOST' in child.get_text():
                    is_superhost = 'True'
                elif '(' and ')' in child.get_text():
                    for c in child:
                        split_rating = c.get_text().split()
                        rating = split_rating[0]
                        num_reviews = split_rating[1].replace('(', '')
                        num_reviews = num_reviews.replace(')', '')

            listings[counter]['is_superhost'] = is_superhost
            listings[counter]['listing_type'] = listing_type
            listings[counter]['rating'] = rating
            listings[counter]['num_reviews'] = num_reviews

            counter += 1

    # GET PRICE PER NIGHT, AMENITIES, HOUSING_INFO
    counter = 0
    for span in spans:
        text = span.get_text()
        if text and '/ night' in text and 'total' not in text:
            price_per_night = None
            amenities = []
            housing_info = []

            # Some have a discounted price so we only want the actual price per night
            price_per_night = text.rsplit('$', 1)[1]
            price_per_night = price_per_night.replace(' / night', '')
            print('ppn', price_per_night)

            # Gets amenities like Wifi/Kitching/Free Parking
            amenities = span.parent.parent.parent.previous_sibling.get_text()
            amenities = amenities.split(' · ')

            # Gets guests, bedrooms, baths
            housing_info = span.parent.parent.parent.previous_sibling.previous_sibling.get_text()
            housing_info = housing_info.split(' · ')

            listings[counter]['price_per_night'] = price_per_night      
            listings[counter]['amenities'] = amenities
            listings[counter]['housing_info'] = housing_info

            counter += 1

    return listings

# %%
soup = getListings('Boston', 'MA', '2020-08-16', '2020-08-22', adults='2', page='2')
pp.pprint(soup)
# Out:
# ppn 134
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 120
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi</div>
# ppn 193
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 89
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 95
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 73
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 112
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 91
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 140
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi</div>
# ppn 109
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 167
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 150
# <div class="_1ulsev2" style="margin-top:4px">Wifi</div>
# ppn 197
# <div class="_1ulsev2" style="margin-top:4px">Wifi</div>
# ppn 82
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi</div>
# ppn 99
# <div class="_1ulsev2" style="margin-top:4px">Wifi</div>
# ppn 204
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 104
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# ppn 82
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi</div>
# ppn 43
# <div class="_1ulsev2" style="margin-top:4px">Free parking<span aria-hidden="true"> · </span>Wifi</div>
# ppn 234
# <div class="_1ulsev2" style="margin-top:4px">Wifi<span aria-hidden="true"> · </span>Kitchen</div>
# [   {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'South End Studio Perfect for Work Travel #26',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '32',
#         'price_per_night': '134',
#         'rating': '4.66',
#         'total_price': '1,010',
#         'url': 'https://www.airbnb.com/rooms/6759439?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '2 beds', '1 private bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Room For Two Short Walk To Harvard (RM 8)',
#         'listing_type': 'Private room',
#         'num_reviews': '5',
#         'price_per_night': '120',
#         'rating': '5.0',
#         'total_price': '822',
#         'url': 'https://www.airbnb.com/rooms/35333477?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Luxury 1BR APT w/ parking by MIT/Harvard/BU/Fenway',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '118',
#         'price_per_night': '193',
#         'rating': '4.94',
#         'total_price': '1,381',
#         'url': 'https://www.airbnb.com/rooms/34944649?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 private bath'],
#         'is_superhost': 'True',
#         'listing_name': '★ The Map Room | Close to Subway + Downtown ★',
#         'listing_type': 'Private room',
#         'num_reviews': '32',
#         'price_per_night': '89',
#         'rating': '4.97',
#         'total_price': '632',
#         'url': 'https://www.airbnb.com/rooms/32895915?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Penthouse Room With Private Entrance',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '143',
#         'price_per_night': '95',
#         'rating': '4.92',
#         'total_price': '730',
#         'url': 'https://www.airbnb.com/rooms/18330818?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': 'R1. Quiet private room near Kendall/MIT',
#         'listing_type': 'Private room',
#         'num_reviews': '134',
#         'price_per_night': '73',
#         'rating': '4.80',
#         'total_price': '511',
#         'url': 'https://www.airbnb.com/rooms/21738836?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '2.5 shared baths'],
#         'is_superhost': 'True',
#         'listing_name': '★ Spacious, Modern & Comfy★Professionally Cleaned!',
#         'listing_type': 'Private room',
#         'num_reviews': '300',
#         'price_per_night': '112',
#         'rating': '4.96',
#         'total_price': '792',
#         'url': 'https://www.airbnb.com/rooms/22327141?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['3 guests', '1 bedroom', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Garden View 3 (private entrance & free parking)',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '28',
#         'price_per_night': '91',
#         'rating': '4.89',
#         'total_price': '704',
#         'url': 'https://www.airbnb.com/rooms/38871127?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '2 beds', '1 private bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Room For Two Short Walk To Harvard (Rm 9)',
#         'listing_type': 'Private room',
#         'num_reviews': '9',
#         'price_per_night': '140',
#         'rating': '4.78',
#         'total_price': '981',
#         'url': 'https://www.airbnb.com/rooms/28801153?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['4 guests', '1 bedroom', '3 beds', '1.5 baths'],
#         'is_superhost': 'True',
#         'listing_name': 'Renovated One Bedroom Apartment Allston, MA.',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '78',
#         'price_per_night': '109',
#         'rating': '4.97',
#         'total_price': '803',
#         'url': 'https://www.airbnb.com/rooms/35001266?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 private bath'],
#         'is_superhost': 'True',
#         'listing_name': '✔Arlington✔Skydeck ✔Walk Score 95✔Full Kitchen',
#         'listing_type': 'Private room',
#         'num_reviews': '293',
#         'price_per_night': '167',
#         'rating': '4.93',
#         'total_price': '1,194',
#         'url': 'https://www.airbnb.com/rooms/990668?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'private studio near Harvard/MIT',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '175',
#         'price_per_night': '150',
#         'rating': '4.93',
#         'total_price': '1,067',
#         'url': 'https://www.airbnb.com/rooms/15512578?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': '2.bostonparkplaza · SUPERIOR ROOM',
#         'listing_type': '',
#         'num_reviews': '0',
#         'price_per_night': '197',
#         'rating': None,
#         'total_price': '1,182',
#         'url': 'https://www.airbnb.com/rooms/43715032?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['3 guests', 'Studio', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Guest Suite w Free Parking -\n10min Train to Boston',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '169',
#         'price_per_night': '82',
#         'rating': '4.93',
#         'total_price': '588',
#         'url': 'https://www.airbnb.com/rooms/28574516?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Quaint studio Apt close to CBD & Universities',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '30',
#         'price_per_night': '99',
#         'rating': '4.93',
#         'total_price': '724',
#         'url': 'https://www.airbnb.com/rooms/37158199?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['3 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Brand New 1 BR | 1 BA on Charles St',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '185',
#         'price_per_night': '204',
#         'rating': '4.95',
#         'total_price': '1,496',
#         'url': 'https://www.airbnb.com/rooms/16693642?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['3 guests', '1 bedroom', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Private Garden Level 1 BR APT W/ Parking in Newton',
#         'listing_type': 'Entire house',
#         'num_reviews': '48',
#         'price_per_night': '104',
#         'rating': '4.96',
#         'total_price': '798',
#         'url': 'https://www.airbnb.com/rooms/33319406?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Newly Renovated Boston College Studio',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '183',
#         'price_per_night': '82',
#         'rating': '4.75',
#         'total_price': '627',
#         'url': 'https://www.airbnb.com/rooms/22886713?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Cozy room! Amazing Location! Great Price!!',
#         'listing_type': 'Private room',
#         'num_reviews': '94',
#         'price_per_night': '43',
#         'rating': '4.86',
#         'total_price': '299',
#         'url': 'https://www.airbnb.com/rooms/37365036?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['5 guests', '2 bedrooms', '2 beds', '1.5 baths'],
#         'is_superhost': 'True',
#         'listing_name': 'Contemporary 2BR in Central Sq! Harvard/MIT',
#         'listing_type': 'Entire condominium',
#         'num_reviews': '111',
#         'price_per_night': '234',
#         'rating': '4.90',
#         'total_price': '1,715',
#         'url': 'https://www.airbnb.com/rooms/19183167?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=836b997d-abc8-4123-bc24-d3ca3cfd730e'}]

# %%
def getSoup(city, state, checkin, checkout, adults='1', page='0', search_type='pagination'):
    # Build the URL
    baseurl = 'https://www.airbnb.com/s/homes?'

    # Add pagination
    items_offset = str(int(page) * 20)
    URL = baseurl + 'search_type=' + search_type + '&items_offset=' + items_offset
    
    # Add location
    query = city + '%2C%20' + state
    URL = URL + '&query=' + query
    
    # Add logistics
    URL = URL + '&checkin=' + checkin + '&checkout=' + checkout + '&adults=' + adults
    print(URL)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')

    return soup

soup = getSoup('Boston', 'MA', '2020-08-16', '2020-08-22', adults='2', page='1')
# Out:
# https://www.airbnb.com/s/homes?search_type=pagination&items_offset=20&query=Boston%2C%20MA&checkin=2020-08-16&checkout=2020-08-22&adults=2

# %%
links = soup.find_all('a')
listings = []
# GET LISTING NAME
for link in links:
    # We just want to add real listings, not all link names
    if link.get('data-check-info-section'):
        listings.append({'listing_name': link.get('aria-label')})

# GET SUPERHOST, LISTING_TYPE, RATING, NUM_REVIEWS
divs = soup.find_all('div')
counter = 0
for div in divs:
    if counter < len(listings) and div.get_text() == listings[counter]['listing_name']:
        is_superhost = 'False'
        listing_type = ''
        rating = None
        num_reviews = '0'
        
        listing_info = div.previous_sibling
        for child in listing_info:
            if 'Entire ' in child.get_text() or 'Private ' in child.get_text():
                listing_type = child.get_text()
            elif 'SUPERHOST' in child.get_text():
                is_superhost = 'True'
            elif '(' and ')' in child.get_text():
                for c in child:
                    split_rating = c.get_text().split()
                    rating = split_rating[0]
                    num_reviews = split_rating[1].replace('(', '')
                    num_reviews = num_reviews.replace(')', '')
        
        listings[counter]['is_superhost'] = is_superhost
        listings[counter]['listing_type'] = listing_type
        listings[counter]['rating'] = rating
        listings[counter]['num_reviews'] = num_reviews
        
        counter += 1
            
# GET TOTAL PRICE
spans = soup.find_all('span')
counter = 0
for span in spans:
    text = span.get_text()
    if text and 'total' in text:
        total = text.replace('$', '')
        total = total.replace(' total', '')
        listings[counter]['total_price'] = total
        counter += 1

# GET PRICE PER NIGHT, AMENITIES, HOUSING_INFO
counter = 0
for span in spans:
    text = span.get_text()
    if text and '/ night' in text and 'total' not in text:
        price_per_night = None
        amenities = []
        housing_info = []

        # Some have a discounted price so we only want the actual price per night
        price_per_night = text.rsplit('$', 1)[1]
        price_per_night = price_per_night.replace(' / night', '')
        
        # Gets amenities like Wifi/Kitching/Free Parking
        amenities = span.parent.parent.parent.previous_sibling.get_text()
        amenities = amenities.split(' · ')
        
        # Gets gusts, bedrooms, baths
        housing_info = span.parent.parent.parent.previous_sibling.previous_sibling.get_text()
        housing_info = housing_info.split(' · ')
        
#         # Gets is_superhost, listing_type, rating, and num_reviews
#         listing_info = span.parent.parent.parent.previous_sibling.previous_sibling.previous_sibling.previous_sibling.children
#         for child in listing_info:
#             if 'Entire ' in child.get_text() or 'Private ' in child.get_text():
#                 listing_type = child.get_text()
#             elif 'SUPERHOST' in child.get_text():
#                 is_superhost = 'True'
#             elif '(' and ')' in child.get_text():
#                 for c in child:
#                     split_rating = c.get_text().split()
#                     rating = split_rating[0]
#                     num_reviews = split_rating[1].replace('(', '')
#                     num_reviews = num_reviews.replace(')', '')

        listings[counter]['price_per_night'] = price_per_night      
        listings[counter]['amenities'] = amenities
        listings[counter]['housing_info'] = housing_info

        counter += 1


pp.pprint(listings)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a453839f95d0> in <module>()
#      66
#      67         # Gets gusts, bedrooms, baths
# ---> 68         housing_info = span.parent.parent.parent.previous_sibling.previous_sibling.get_text()
#      69         housing_info = housing_info.split(' · ')
#      70
#
# AttributeError: 'NoneType' object has no attribute 'get_text'
