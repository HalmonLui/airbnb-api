# %%
import requests
import pprint
from bs4 import BeautifulSoup

# Get listing info
# URL = 'https://www.airbnb.com/s/homes?search_type=pagination&query=Boston%2C%20MA&checkin=2020-08-16&checkout=2020-08-22&adults=2&items_offset=0'
def getListings(city, state, checkin, checkout, adults='1', page='0', search_type='pagination'):
    # Build the URL
    baseurl = 'https://www.airbnb.com/s/homes?'

    # Add pagination
    items_offset = str(int(page) * 20)
    URL = baseurl + 'search_type=' + search_type + '&items_offset=' + items_offset
    
    # Add location
    query = city + '%2C%20' + state
    URL = URL + '&query=' + query
    
    # Add logistics
    URL = URL + '&checkin=' + checkin + '&checkout=' + checkout + '&adults=' + adults
    
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')

    listings = []

    links = soup.find_all('a')
    # GET LISTING NAME AND URL
    counter = 0
    for link in links:
        # We just want to add real listings, not all link names
        if link.get('data-check-info-section'):
            listing_name = link.get('aria-label')
            url = 'https://www.airbnb.com' + link.get('href')
            listings.append({'listing_name': listing_name, 'url': url})
            counter += 1

    # GET TOTAL PRICE
    spans = soup.find_all('span')
    counter = 0
    for span in spans:
        text = span.get_text()
        if text and 'total' in text:
            total = text.replace('$', '')
            total = total.replace(' total', '')
            listings[counter]['total_price'] = total
            counter += 1

    # GET PRICE PER NIGHT, AMENITIES, HOUSING_INFO, SUPERHOST, LISTING_TYPE, RATING, NUM_REVIEWS
    counter = 0
    for span in spans:
        text = span.get_text()
        if text and '/ night' in text and 'total' not in text:
            price_per_night = None
            amenities = []
            housing_info = []
            is_superhost = 'False'
            listing_type = ''
            rating = None
            num_reviews = '0'

            # Some have a discounted price so we only want the actual price per night
            price_per_night = text.rsplit('$', 1)[1]
            price_per_night = price_per_night.replace(' / night', '')

            # Gets amenities like Wifi/Kitching/Free Parking
            amenities = span.parent.parent.parent.previous_sibling.get_text()
            amenities = amenities.split(' · ')

            # Gets gusts, bedrooms, baths
            housing_info = span.parent.parent.parent.previous_sibling.previous_sibling.get_text()
            housing_info = housing_info.split(' · ')

            # Gets is_superhost, listing_type, rating, and num_reviews
            listing_info = span.parent.parent.parent.previous_sibling.previous_sibling.previous_sibling.previous_sibling.children
            for child in listing_info:
                child_text = child.get_text()
                if 'Entire ' in child_text or 'Private ' in child_text:
                    listing_type = child_text
                elif 'SUPERHOST' in child_text:
                    is_superhost = 'True'
                elif '(' and ')' in child_text:
                    for c in child:
                        split_rating = c.get_text().split()
                        rating = split_rating[0]
                        num_reviews = split_rating[1].replace('(', '')
                        num_reviews = num_reviews.replace(')', '')

            listings[counter]['price_per_night'] = price_per_night      
            listings[counter]['amenities'] = amenities
            listings[counter]['housing_info'] = housing_info
            listings[counter]['is_superhost'] = is_superhost
            listings[counter]['listing_type'] = listing_type
            listings[counter]['rating'] = rating
            listings[counter]['num_reviews'] = num_reviews
            counter += 1

    return listings

# %%
pp = pprint.PrettyPrinter(indent=4)
soup = getListings('Boston', 'MA', '2020-08-16', '2020-08-22', adults='2', page='2')
pp.pprint(soup)
# Out:
# [   {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Minutes to/from Logan - Ocean view',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '81',
#         'price_per_night': '96',
#         'rating': '4.84',
#         'total_price': '668',
#         'url': 'https://www.airbnb.com/rooms/22631832?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'On the Hill|Historic Boston|Studio #3',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '27',
#         'price_per_night': '102',
#         'rating': '4.37',
#         'total_price': '799',
#         'url': 'https://www.airbnb.com/rooms/19309861?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Downtown Beacon Hill, Convenient, Comfy Studio#10',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '161',
#         'price_per_night': '95',
#         'rating': '4.72',
#         'total_price': '729',
#         'url': 'https://www.airbnb.com/rooms/8732121?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '2 baths'],
#         'is_superhost': 'True',
#         'listing_name': 'City Beauty-comfortable and safe Apt 3 Room 2',
#         'listing_type': 'Private room',
#         'num_reviews': '11',
#         'price_per_night': '58',
#         'rating': '4.73',
#         'total_price': '429',
#         'url': 'https://www.airbnb.com/rooms/37569179?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Modern and comfortable studio apartment',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '30',
#         'price_per_night': '92',
#         'rating': '4.97',
#         'total_price': '696',
#         'url': 'https://www.airbnb.com/rooms/35386911?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Large Sunny room w/ King bed (Boston Harbor Room)',
#         'listing_type': 'Private room',
#         'num_reviews': '75',
#         'price_per_night': '55',
#         'rating': '4.89',
#         'total_price': '437',
#         'url': 'https://www.airbnb.com/rooms/33158116?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '0 beds', '1 shared bath'],
#         'is_superhost': 'False',
#         'listing_name': '☆ Relaxing & Peaceful Room - Free Parking ☆',
#         'listing_type': 'Private room',
#         'num_reviews': '13',
#         'price_per_night': '40',
#         'rating': '4.46',
#         'total_price': '338',
#         'url': 'https://www.airbnb.com/rooms/38850930?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Treetop Haven in the City',
#         'listing_type': 'Entire house',
#         'num_reviews': '193',
#         'price_per_night': '92',
#         'rating': '4.86',
#         'total_price': '700',
#         'url': 'https://www.airbnb.com/rooms/210097?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '0 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Comfy Newton Guesthouse',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '44',
#         'price_per_night': '70',
#         'rating': '4.82',
#         'total_price': '606',
#         'url': 'https://www.airbnb.com/rooms/28988848?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': '15min T to Downtown, Walk to airport & subway',
#         'listing_type': 'Private room',
#         'num_reviews': '178',
#         'price_per_night': '50',
#         'rating': '4.89',
#         'total_price': '379',
#         'url': 'https://www.airbnb.com/rooms/29134558?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1.5 shared baths'],
#         'is_superhost': 'True',
#         'listing_name': "1880's Boston Townhouse on Redline,Private Bathrm",
#         'listing_type': 'Private room',
#         'num_reviews': '336',
#         'price_per_night': '57',
#         'rating': '4.98',
#         'total_price': '399',
#         'url': 'https://www.airbnb.com/rooms/19117781?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['4 guests', '2 bedrooms', '2 beds', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Safe Self check in 2bedroom 15 min to Boston Train',
#         'listing_type': 'Entire condominium',
#         'num_reviews': '58',
#         'price_per_night': '101',
#         'rating': '4.68',
#         'total_price': '788',
#         'url': 'https://www.airbnb.com/rooms/13395219?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': "Studio, w kitchenette, in owner's Beacon Hill home",
#         'listing_type': 'Entire apartment',
#         'num_reviews': '104',
#         'price_per_night': '165',
#         'rating': '4.83',
#         'total_price': '1,155',
#         'url': 'https://www.airbnb.com/rooms/2126053?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['3 guests', 'Studio', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Studio / across from West Medford commuter rail',
#         'listing_type': 'Entire condominium',
#         'num_reviews': '81',
#         'price_per_night': '100',
#         'rating': '4.67',
#         'total_price': '764',
#         'url': 'https://www.airbnb.com/rooms/27195033?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['4 guests', '1 bedroom', '3 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Charming Back Bay, Beacon St. Apt. w/ Private Roof',
#         'listing_type': 'Entire condominium',
#         'num_reviews': '22',
#         'price_per_night': '250',
#         'rating': '4.86',
#         'total_price': '1,740',
#         'url': 'https://www.airbnb.com/rooms/37630538?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Harvard Law - Cozy Double or Cool Single',
#         'listing_type': 'Private room',
#         'num_reviews': '16',
#         'price_per_night': '90',
#         'rating': '4.87',
#         'total_price': '662',
#         'url': 'https://www.airbnb.com/rooms/38960050?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'False',
#         'listing_name': "MIT/Harvard - Artist's Pad in Central Sq (Room A)",
#         'listing_type': 'Private room',
#         'num_reviews': '65',
#         'price_per_night': '58',
#         'rating': '4.84',
#         'total_price': '411',
#         'url': 'https://www.airbnb.com/rooms/25738590?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Guest House - Private Full Room w/ Shared Bathroom',
#         'listing_type': 'Private room',
#         'num_reviews': '0',
#         'price_per_night': '51',
#         'rating': None,
#         'total_price': '412',
#         'url': 'https://www.airbnb.com/rooms/43276486?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Ocean View Guest Suite (Private Bath & Entry)',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '260',
#         'price_per_night': '106',
#         'rating': '4.95',
#         'total_price': '779',
#         'url': 'https://www.airbnb.com/rooms/19830673?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['4 guests', 'Studio', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Remodeled Suite w/ Roof Deck & Downtown View',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '51',
#         'price_per_night': '188',
#         'rating': '5.0',
#         'total_price': '1,331',
#         'url': 'https://www.airbnb.com/rooms/38551361?adults=2&check_in=2020-08-16&check_out=2020-08-22&previous_page_section_name=1000&federated_search_id=2906afcd-a567-4328-92b5-7c674368dac4'}]

# %%
def getSoup(city, state, checkin, checkout, adults='1', page='0', search_type='pagination'):
    # Build the URL
    baseurl = 'https://www.airbnb.com/s/homes?'

    # Add pagination
    items_offset = str(int(page) * 20)
    URL = baseurl + 'search_type=' + search_type + '&items_offset=' + items_offset
    
    # Add location
    query = city + '%2C%20' + state
    URL = URL + '&query=' + query
    
    # Add logistics
    URL = URL + '&checkin=' + checkin + '&checkout=' + checkout + '&adults=' + adults
    print(URL)
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')

    return soup

soup = getSoup('Boston', 'MA', '2020-08-16', '2020-08-22', adults='2', page='1')
# Out:
# https://www.airbnb.com/s/homes?search_type=pagination&items_offset=20&query=Boston%2C%20MA&checkin=2020-08-16&checkout=2020-08-22&adults=2

# %%
links = soup.find_all('a')
listings = []
# GET LISTING NAME
for link in links:
    # We just want to add real listings, not all link names
    if link.get('data-check-info-section'):
        listings.append({'listing_name': link.get('aria-label')})

# GET TOTAL PRICE
spans = soup.find_all('span')
counter = 0
for span in spans:
    text = span.get_text()
    if text and 'total' in text:
        total = text.replace('$', '')
        total = total.replace(' total', '')
        listings[counter]['total_price'] = total
        counter += 1

# GET PRICE PER NIGHT, AMENITIES, HOUSING_INFO, SUPERHOST, LISTING_TYPE, RATING, NUM_REVIEWS
counter = 0
for span in spans:
    text = span.get_text()
    if text and '/ night' in text and 'total' not in text:
        price_per_night = None
        amenities = []
        housing_info = []
        is_superhost = 'False'
        listing_type = ''
        rating = None
        num_reviews = '0'

        # Some have a discounted price so we only want the actual price per night
        price_per_night = text.rsplit('$', 1)[1]
        price_per_night = price_per_night.replace(' / night', '')
        
        # Gets amenities like Wifi/Kitching/Free Parking
        amenities = span.parent.parent.parent.previous_sibling.get_text()
        amenities = amenities.split(' · ')
        
        # Gets gusts, bedrooms, baths
        housing_info = span.parent.parent.parent.previous_sibling.previous_sibling.get_text()
        housing_info = housing_info.split(' · ')
        
        # Gets is_superhost, listing_type, rating, and num_reviews
        listing_info = span.parent.parent.parent.previous_sibling.previous_sibling.previous_sibling.previous_sibling.children
        for child in listing_info:
            if 'Entire ' in child.get_text() or 'Private ' in child.get_text():
                listing_type = child.get_text()
            elif 'SUPERHOST' in child.get_text():
                is_superhost = 'True'
            elif '(' and ')' in child.get_text():
                for c in child:
                    split_rating = c.get_text().split()
                    rating = split_rating[0]
                    num_reviews = split_rating[1].replace('(', '')
                    num_reviews = num_reviews.replace(')', '')

        listings[counter]['price_per_night'] = price_per_night      
        listings[counter]['amenities'] = amenities
        listings[counter]['housing_info'] = housing_info
        listings[counter]['is_superhost'] = is_superhost
        listings[counter]['listing_type'] = listing_type
        listings[counter]['rating'] = rating
        listings[counter]['num_reviews'] = num_reviews
        counter += 1


pp.pprint(listings)
# Out:
# [   {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Stylish Downtown Studio in the SouthEnd, #8',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '97',
#         'price_per_night': '82',
#         'rating': '4.59',
#         'total_price': '673'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['3 guests', '1 bedroom', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Sunny and cozy home near one end of freedom trail',
#         'listing_type': 'Entire house',
#         'num_reviews': '233',
#         'price_per_night': '129',
#         'rating': '4.91',
#         'total_price': '933'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['5 guests', '2 bedrooms', '3 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Park view 2 (private entrance & free parking)',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '15',
#         'price_per_night': '89',
#         'rating': '5.0',
#         'total_price': '713'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Cozy private basement apt in Somerville w/ parking',
#         'listing_type': 'Entire house',
#         'num_reviews': '86',
#         'price_per_night': '109',
#         'rating': '4.95',
#         'total_price': '789'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1.5 baths'],
#         'is_superhost': 'False',
#         'listing_name': 'Beautiful 1-bedroom apartment/2nd floor',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '4',
#         'price_per_night': '110',
#         'rating': '4.75',
#         'total_price': '896'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1.5 shared baths'],
#         'is_superhost': 'True',
#         'listing_name': "1880's Boston Townhouse on Redline,Private Bathrm",
#         'listing_type': 'Private room',
#         'num_reviews': '336',
#         'price_per_night': '57',
#         'rating': '4.98',
#         'total_price': '399'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Newly Renovated Boston College Studio',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '183',
#         'price_per_night': '82',
#         'rating': '4.75',
#         'total_price': '640'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Zakim Room-Walk to Subway&Logan airport',
#         'listing_type': 'Private room',
#         'num_reviews': '181',
#         'price_per_night': '45',
#         'rating': '4.85',
#         'total_price': '345'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Ocean View Guest Suite (Private Bath & Entry)',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '260',
#         'price_per_night': '106',
#         'rating': '4.95',
#         'total_price': '779'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['3 guests', '1 bedroom', '2 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Flat in the Jamaica Plain Hills',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '38',
#         'price_per_night': '127',
#         'rating': '4.84',
#         'total_price': '925'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', 'Studio', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Uniquely Boston PVT Entry/BATH QN Bed  Cont BFast!',
#         'listing_type': 'Entire guest suite',
#         'num_reviews': '156',
#         'price_per_night': '140',
#         'rating': '4.94',
#         'total_price': '965'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 shared bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Cozy Room 1 Close to downtown & seaport district.',
#         'listing_type': 'Private room',
#         'num_reviews': '98',
#         'price_per_night': '40',
#         'rating': '4.81',
#         'total_price': '332'},
#     {   'amenities': ['Free parking', 'Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Garden level apt-Near Boston/Airport/Beach/Train',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '9',
#         'price_per_night': '84',
#         'rating': '5.0',
#         'total_price': '610'},
#     {   'amenities': ['Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 private bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Modern Guest Room, Private Bath near airport/city',
#         'listing_type': 'Private room',
#         'num_reviews': '536',
#         'price_per_night': '82',
#         'rating': '4.81',
#         'total_price': '583'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['4 guests', '2 bedrooms', '3 beds', '1 bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Two Bedroom Apartment, Parking Included.',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '322',
#         'price_per_night': '80',
#         'rating': '4.67',
#         'total_price': '595'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Spacious, private apartment in perfect location',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '65',
#         'price_per_night': '98',
#         'rating': '4.86',
#         'total_price': '725'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['4 guests', 'Studio', '2 beds', '1 private bath'],
#         'is_superhost': 'False',
#         'listing_name': 'Back Bay Guest House:  2 Beds in Private Studio',
#         'listing_type': 'Private room',
#         'num_reviews': '0',
#         'price_per_night': '71',
#         'rating': None,
#         'total_price': '573'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['6 guests', '2 bedrooms', '3 beds', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': '★Coolidge Corner 2BR★1 FREE Parking★Walk to T',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '224',
#         'price_per_night': '129',
#         'rating': '4.88',
#         'total_price': '1,002'},
#     {   'amenities': ['Free parking', 'Wifi', 'Kitchen'],
#         'housing_info': ['4 guests', '1 bedroom', '3 beds', '1.5 baths'],
#         'is_superhost': 'True',
#         'listing_name': 'Renovated One Bedroom Apartment Allston, MA.',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '78',
#         'price_per_night': '109',
#         'rating': '4.97',
#         'total_price': '821'},
#     {   'amenities': ['Wifi'],
#         'housing_info': ['2 guests', '1 bedroom', '1 bed', '1 bath'],
#         'is_superhost': 'True',
#         'listing_name': 'Quaint studio Apt close to CBD & Universities',
#         'listing_type': 'Entire apartment',
#         'num_reviews': '30',
#         'price_per_night': '99',
#         'rating': '4.93',
#         'total_price': '710'}]
